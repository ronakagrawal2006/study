# %% [markdown]
# ![image.png](attachment:4d6d6d0b-2cbe-4cca-9e03-2c77ec4fc56d.png)

# %% [markdown]
# ![image.png](attachment:46bc9906-bc3c-4aad-b7f6-11bf5012e479.png)

# %% [markdown]
# https://www.khanacademy.org/math/statistics-probability/counting-permutations-and-combinations/combinatorics-probability/v/conditional-probability-and-combinations

# %% [markdown]
# ![image.png](attachment:d556ce98-74ba-4fef-9bc8-4a542e6f0c09.png)

# %% [markdown]
# https://www.khanacademy.org/math/statistics-probability/counting-permutations-and-combinations/combinatorics-probability/v/birthday-probability-problem

# %% [markdown]
# ![image.png](attachment:1b49866f-4cd9-4333-89d6-fe806f1bbc6c.png)
