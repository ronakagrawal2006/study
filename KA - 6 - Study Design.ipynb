# %% [markdown]
# * Sampling problems:
#  - Voluntary Response Sampling - the responding group leaning towards an outome
#  - Under Coverage
#  - Response bias - have you lied to your parents?
#  - Non Response
#  - Convinience Sampling - the targeted group leaning towards an outcome
#  - Voluntary Response Sampling

# %% [markdown]
# Sampling Techniques:

# %% [markdown]
# ![image.png](attachment:e48bc591-07cc-4994-ac6c-f016532f33f7.png)

# %% [markdown]
# ![image.png](attachment:c860046c-d7ba-4d8d-9ef4-1c18b775d251.png)

# %% [markdown]
# ![image.png](attachment:ef106c9e-da3f-4e5e-a1d5-87f8bbbf431c.png)
